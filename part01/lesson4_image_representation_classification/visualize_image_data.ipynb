# %%
import cv2 # computer vision library
import helpers

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %%
# training and test data directory

train_image_directory = "day_night_images/training/"
test_image_directory = "day_night_images/test/"

# %%
# load dataset from helper function

Image_list = helpers.load_dataset(train_image_directory)

# %%
# visualize input
# Select an image and its label by list index
image_index = 0
selected_image = Image_list[image_index][0]
selected_label = Image_list[image_index][1]

## TODO: Print out 1. The shape of the image and 2. The image's label `selected_label`
print(selected_image.shape)
print(selected_label)
plt.imshow(selected_image)
# Out:
# (471, 640, 3)
# day

# %%
# end of program
