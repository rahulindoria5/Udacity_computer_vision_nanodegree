# %% [markdown]
# # RGB colorspace

# %% [markdown]
# ### Import resources

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %% [markdown]
# ### Read in an image

# %%
# Read in the image
image = mpimg.imread('images/wa_state_highway.jpg')

plt.imshow(image)

# %% [markdown]
# ### RGB channels
#
# Visualize the levels of each color channel. Pay close attention to the traffic signs!

# %%
# split image into channels (RGB)
r = image[:, :, 0]
g = image[:, :, 1]
b = image[:, :, 2]


#create subplots for visualizing every channel
fig, (axes1, axes2, axes3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 15))

#set title of subplot
axes1.set_title('red channel')
axes2.set_title('green channel')
axes3.set_title('blue channel')
#visualize channel
axes1.imshow(r, cmap='gray')
axes2.imshow(g, cmap='gray')
axes3.imshow(b, cmap='gray')
